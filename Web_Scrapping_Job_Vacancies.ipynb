# %% [markdown]
# # Web Scraping Job Vacancies

# %% [markdown]
#  ## Introduction
#
# In this project, we'll build a web scraper to extract job listings from a popular job search platform. We'll extract job titles, companies, locations, job descriptions, and other relevant information.
#
# Here are the main steps we'll follow in this project:
#
# 1. Setup our development environment
# 2. Understand the basics of web scraping
# 3. Analyze the website structure of our job search platform
# 4. Write the Python code to extract job data from our job search platform
# 5. Save the data to a CSV file
# 6. Test our web scraper and refine our code as needed
#
# ## Prerequisites
#
# Before starting this project, you should have some basic knowledge of Python programming and HTML structure. In addition, you may want to use the following packages in your Python environment:
#
# - requests
# - BeautifulSoup
# - csv
# - datetime

# %% [markdown]
# ## Task 1 – Import required libraries:

# %%
import csv
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Task 2 – Generating a URL with a function:

# %%
base_url = requests.get('https://careers.coursera.com/jobs/search')

# %%
base_url.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n  <head>\n      <meta name="google-site-verification" content="8Ox5Zr13P_8Yvn6C1nmk9TGpWDW9nNpMOY66B2rIFRQ" />\n    <title>Search Page</title>\n    <script type="importmap" data-turbo-track="reload" nonce="3ShwjkmfQN/GXOvB0xuCWQ==">{\n  "imports": {\n    "bootstrap": "https://ga.jspm.io/npm:bootstrap@5.3.2/dist/js/bootstrap.js",\n    "bootstrap4": "https://ga.jspm.io/npm:bootstrap@4.6.2/dist/js/bootstrap.js",\n    "bootstrap4/js/dist/toast": "https://ga.jspm.io/npm:bootstrap@4.6.2/js/dist/toast.js",\n    "bootstrap3": "https://ga.jspm.io/npm:bootstrap@3.4.1/dist/js/bootstrap.js",\n    "@popperjs/core": "https://ga.jspm.io/npm:@popperjs/core@2.11.8/lib/index.js",\n    "popper.js": "https://ga.jspm.io/npm:popper.js@1.16.1/dist/umd/popper.js",\n    "@hotwired/stimulus": "https://ga.jspm.io/npm:@hotwired/stimulus@3.2.2/dist/stimulus.js",\n    "@hotwired/stimulus-loading": "/assets/stimulus-loading-1fc53fe7a488db9281d2ff88509e8f45d6119ee4.js",\n    "@hotwired/turbo-rails": "https://ga.jspm.io/npm:@hotwired/turbo-rails@7.3.0/app/javascript/turbo/index.js",\n    "@hotwired/turbo": "https://ga.jspm.io/npm:@hotwired/turbo@7.3.0/dist/turbo.es2017-esm.js",\n    "@rails/actioncable/src": "https://ga.jspm.io/npm:@rails/actioncable@7.1.2/src/index.js",\n    "video.js": "https://ga.jspm.io/npm:video.js@8.6.1/dist/video.es.js",\n    "@babel/runtime/helpers/extends": "https://ga.jspm.io/npm:@babel/runtime@7.23.6/helpers/esm/extends.js",\n    "@videojs/vhs-utils/es/byte-helpers": "https://ga.jspm.io/npm:@videojs/vhs-utils@4.0.0/es/byte-helpers.js",\n    "@videojs/vhs-utils/es/containers": "https://ga.jspm.io/npm:@videojs/vhs-utils@4.0.0/es/containers.js",\n    "@videojs/vhs-utils/es/decode-b64-to-uint8-array": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/decode-b64-to-uint8-array.js",\n    "@videojs/vhs-utils/es/": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/",\n    "@videojs/vhs-utils/es/id3-helpers": "https://ga.jspm.io/npm:@videojs/vhs-utils@4.0.0/es/id3-helpers.js",\n    "@videojs/vhs-utils/es/media-groups": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/media-groups.js",\n    "@videojs/vhs-utils/es/resolve-url": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/resolve-url.js",\n    "@videojs/xhr": "https://ga.jspm.io/npm:@videojs/xhr@2.6.0/lib/index.js",\n    "@xmldom/xmldom": "https://ga.jspm.io/npm:@xmldom/xmldom@0.8.10/lib/index.js",\n    "dom-walk": "https://ga.jspm.io/npm:dom-walk@0.1.2/index.js",\n    "global/document": "https://ga.jspm.io/npm:global@4.4.0/document.js",\n    "global/window": "https://ga.jspm.io/npm:global@4.4.0/window.js",\n    "is-function": "https://ga.jspm.io/npm:is-function@1.0.2/index.js",\n    "keycode": "https://ga.jspm.io/npm:keycode@2.2.0/index.js",\n    "m3u8-parser": "https://ga.jspm.io/npm:m3u8-parser@6.2.0/dist/m3u8-parser.es.js",\n    "min-document": "https://ga.jspm.io/npm:min-document@2.19.0/index.js",\n    "mpd-parser": "https://ga.jspm.io/npm:mpd-parser@1.2.2/dist/mpd-parser.es.js",\n    "mux.js/lib/tools/parse-sidx": "https://ga.jspm.io/npm:mux.js@6.3.0/lib/tools/parse-sidx.js",\n    "mux.js/lib/utils/clock": "https://ga.jspm.io/npm:mux.js@6.3.0/lib/utils/clock.js",\n    "safe-json-parse/tuple": "https://ga.jspm.io/npm:safe-json-parse@4.0.0/tuple.js",\n    "url-toolkit": "https://ga.jspm.io/npm:url-toolkit@2.2.5/src/url-toolkit.js",\n    "videojs-vtt.js": "https://ga.jspm.io/npm:videojs-vtt.js@0.15.5/lib/browser-index.js",\n    "videojs-youtube": "https://ga.jspm.io/npm:videojs-youtube@3.0.1/dist/Youtube.js",\n    "jquery": "https://ga.jspm.io/npm:jquery@3.7.1/dist/jquery.js",\n    "rails-ujs": "https://ga.jspm.io/npm:rails-ujs@5.2.8-1/lib/assets/compiled/rails-ujs.js",\n    "urijs": "https://ga.jspm.io/npm:urijs@1.19.11/src/URI.js",\n    "js-cookie": "https://ga.jspm.io/npm:js-cookie@3.0.5/dist/js.cookie.mjs",\n    "selectize": "https://ga.jspm.io/npm:selectize@0.12.6/dist/js/selectize.js",\n    "intl-tel-input": "https://ga.jspm.io/npm ...

# %% [markdown]
# ## Task 3 – Extract the Job Data from a single job posting card:
#
#
# *  Define a function that takes a Beautiful Soup object representing a job posting and extracts relevant information.

# %%
soup = BeautifulSoup(base_url.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta content="8Ox5Zr13P_8Yvn6C1nmk9TGpWDW9nNpMOY66B2rIFRQ" name="google-site-verification"/>
# <title>Search Page</title>
# <script data-turbo-track="reload" nonce="3ShwjkmfQN/GXOvB0xuCWQ==" type="importmap">{
#   "imports": {
#     "bootstrap": "https://ga.jspm.io/npm:bootstrap@5.3.2/dist/js/bootstrap.js",
#     "bootstrap4": "https://ga.jspm.io/npm:bootstrap@4.6.2/dist/js/bootstrap.js",
#     "bootstrap4/js/dist/toast": "https://ga.jspm.io/npm:bootstrap@4.6.2/js/dist/toast.js",
#     "bootstrap3": "https://ga.jspm.io/npm:bootstrap@3.4.1/dist/js/bootstrap.js",
#     "@popperjs/core": "https://ga.jspm.io/npm:@popperjs/core@2.11.8/lib/index.js",
#     "popper.js": "https://ga.jspm.io/npm:popper.js@1.16.1/dist/umd/popper.js",
#     "@hotwired/stimulus": "https://ga.jspm.io/npm:@hotwired/stimulus@3.2.2/dist/stimulus.js",
#     "@hotwired/stimulus-loading": "/assets/stimulus-loading-1fc53fe7a488db9281d2ff88509e8f45d6119ee4.js",
#     "@hotwired/turbo-rails": "https://ga.jspm.io/npm:@hotwired/turbo-rails@7.3.0/app/javascript/turbo/index.js",
#     "@hotwired/turbo": "https://ga.jspm.io/npm:@hotwired/turbo@7.3.0/dist/turbo.es2017-esm.js",
#     "@rails/actioncable/src": "https://ga.jspm.io/npm:@rails/actioncable@7.1.2/src/index.js",
#     "video.js": "https://ga.jspm.io/npm:video.js@8.6.1/dist/video.es.js",
#     "@babel/runtime/helpers/extends": "https://ga.jspm.io/npm:@babel/runtime@7.23.6/helpers/esm/extends.js",
#     "@videojs/vhs-utils/es/byte-helpers": "https://ga.jspm.io/npm:@videojs/vhs-utils@4.0.0/es/byte-helpers.js",
#     "@videojs/vhs-utils/es/containers": "https://ga.jspm.io/npm:@videojs/vhs-utils@4.0.0/es/containers.js",
#     "@videojs/vhs-utils/es/decode-b64-to-uint8-array": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/decode-b64-to-uint8-array.js",
#     "@videojs/vhs-utils/es/": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/",
#     "@videojs/vhs-utils/es/id3-helpers": "https://ga.jspm.io/npm:@videojs/vhs-utils@4.0.0/es/id3-helpers.js",
#     "@videojs/vhs-utils/es/media-groups": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/media-groups.js",
#     "@videojs/vhs-utils/es/resolve-url": "https://ga.jspm.io/npm:@videojs/vhs-utils@3.0.5/es/resolve-url.js",
#     "@videojs/xhr": "https://ga.jspm.io/npm:@videojs/xhr@2.6.0/lib/index.js",
#     "@xmldom/xmldom": "https://ga.jspm.io/npm:@xmldom/xmldom@0.8.10/lib/index.js",
#     "dom-walk": "https://ga.jspm.io/npm:dom-walk@0.1.2/index.js",
#     "global/document": "https://ga.jspm.io/npm:global@4.4.0/document.js",
#     "global/window": "https://ga.jspm.io/npm:global@4.4.0/window.js",
#     "is-function": "https://ga.jspm.io/npm:is-function@1.0.2/index.js",
#     "keycode": "https://ga.jspm.io/npm:keycode@2.2.0/index.js",
#     "m3u8-parser": "https://ga.jspm.io/npm:m3u8-parser@6.2.0/dist/m3u8-parser.es.js",
#     "min-document": "https://ga.jspm.io/npm:min-document@2.19.0/index.js",
#     "mpd-parser": "https://ga.jspm.io/npm:mpd-parser@1.2.2/dist/mpd-parser.es.js",
#     "mux.js/lib/tools/parse-sidx": "https://ga.jspm.io/npm:mux.js@6.3.0/lib/tools/parse-sidx.js",
#     "mux.js/lib/utils/clock": "https://ga.jspm.io/npm:mux.js@6.3.0/lib/utils/clock.js",
#     "safe-json-parse/tuple": "https://ga.jspm.io/npm:safe-json-parse@4.0.0/tuple.js",
#     "url-toolkit": "https://ga.jspm.io/npm:url-toolkit@2.2.5/src/url-toolkit.js",
#     "videojs-vtt.js": "https://ga.jspm.io/npm:videojs-vtt.js@0.15.5/lib/browser-index.js",
#     "videojs-youtube": "https://ga.jspm.io/npm:videojs-youtube@3.0.1/dist/Youtube.js",
#     "jquery": "https://ga.jspm.io/npm:jquery@3.7.1/dist/jquery.js",
#     "rails-ujs": "https://ga.jspm.io/npm:rails-ujs@5.2.8-1/lib/assets/compiled/rails-ujs.js",
#     "urijs": "https://ga.jspm.io/npm:urijs@1.19.11/src/URI.js",
#     "js-cookie": "https://ga.jspm.io/npm:js-cookie@3.0.5/dist/js.cookie.mjs",
#     "selectize": "https://ga.jspm.io/npm:selectize@0.12.6/dist/js/selectize.js",
#     "intl-tel-input": "https://ga.jspm.io/npm:intl-tel-input@18.3.4/index.js",
#     "intl-tel-input/build/js/utils.js": "https://ga.jspm.io/npm:intl-tel-input@18.3.4/build/js/utils.js",
#     "@googlemaps/markerclustererplus": "https://ga.jspm.io/npm:@googlemaps/markerclustererplus@1.2.10/dist/index.esm.js",
#     "sifter": "https://ga.jspm.io/npm:sifter@0.5.4/sifter.js",
#     "microplugin": "https://ga.jspm.io/npm:microplugin@0.0.3/src/microplugin.js",
#     "public/apply_url": "/assets/public/apply_url-26c99f5a8d783f5118c79b95ab6776e56c1887c0.js",
#     "public/beacons/abstract_beacon": "/assets/public/beacons/abstract_beacon-b08e92f42f82caebf85dfed921cc9e4cc65e1bd2.js",
#     "public/beacons/abstract_view_beacon": "/assets/public/beacons/abstract_view_beacon-d4f27ea9593bcafde9478c6610014383e5932bd5.js",
#     "public/beacons/location_beacon": "/assets/public/beacons/location_beacon-cac23ae5e2b59a06017841155e8a967adf38f3bd.js",
#     "public/beacons/page_events_beacon": "/assets/public/beacons/page_events_beacon-0bc368ad8a80d1b3c27714de0dd2007f0167976d.js",
#     "public/beacons/video_beacon": "/assets/public/beacons/video_beacon-feacc47520f1634e150b5ce531496353f39de485.js",
#     "public/beacons/view_beacon": "/assets/public/beacons/view_beacon-8d9cc5fa4edce0fd72f26e7eda523ce22a47ac97.js",
#     "public/boot": "/assets/public/boot-a1016b34c5aba4ce5978cefe0aa258d15aa23776.js",
#     "public/bootstrap5": "/assets/public/bootstrap5-1ac14a6c1e70053869c3a7ae7d71739ad145d28a.js",
#     "public/candidate_populator": "/assets/public/candidate_populator-5388bbb3d8f484a34e7affe6db72d60dd7880506.js",
#     "public/chatbot": "/assets/public/chatbot-c41028f113ebf06a662dc6fc0140b9f47e4ab664.js",
#     "public/common_pages": "/assets/public/common_pages-efcfef346a02eff0d7083380d4034959e4904d7b.js",
#     "public/controllers/application": "/assets/public/controllers/application-3f2f75711063fad43be536f6c6bae842b86eba67.js",
#     "public/controllers/blocks/call_to_action_controller": "/assets/public/controllers/blocks/call_to_action_controller-acc70f5d6930739a6fcac4f0e8c98caf16b617ac.js",
#     "public/controllers/blocks/candidate_favourite_controller": "/assets/public/controllers/blocks/candidate_favourite_controller-4d3a15070652f7e26c62df394bc0f836ceea9591.js",
#     "public/controllers/blocks/carousel/video_block_controller": "/assets/public/controllers/blocks/carousel/video_block_controller-afb20fe42c6068e1caaad4ff7c215885fe54ef18.js",
#     "public/controllers/blocks/google_map/map_controller": "/assets/public/controllers/blocks/google_map/map_controller-99c9f03a7cc214018f71b6bd00d112a33b641c67.js",
#     "public/controllers/blocks/job_search_form_controller": "/assets/public/controllers/blocks/job_search_form_controller-15e9c9f632cbc25f61a78a85caa5bd61b876628b.js",
#     "public/controllers/blocks/jobs_controller": "/assets/public/controllers/blocks/jobs_controller-046289f49531762924503ea0e671c6242b27d95b.js",
#     "public/controllers/blocks/linked_image_controller": "/assets/public/controllers/blocks/linked_image_controller-af416b1d69b4123608a35f0f2a3a3b3a5ac95bdd.js",
#     "public/controllers/blocks/near_me_controller": "/assets/public/controllers/blocks/near_me_controller-b1e38038265d3326cdd0f17fc67d96fe676b501e.js",
#     "public/controllers/candidate/sign_out_controller": "/assets/public/controllers/candidate/sign_out_controller-d674e9d36d8b37e33cff4c1b3e5ccb0c6ddfb93c.js",
#     "public/controllers/exit_call_to_action_modal_controller": "/assets/public/controllers/exit_call_to_action_modal_controller-06ddf63a89c946a7e21a49790ffee9393329e2b6.js",
#     "public/controllers": "/assets/public/controllers/index-9d3b6133423b87cbe6c35d5dbeeb59c6d03f5a25.js",
#     "public/controllers/init/explicit_consent_modal_controller": "/assets/public/controllers/init/explicit_consent_modal_controller-ab3c022ec1ac9d8458f359686afac0acaba19ad0.js",
#     "public/controllers/init/implied_consent_controller": "/assets/public/controllers/init/implied_consent_controller-ea52c6bd60eb9e776ff2aff6b8014c7e4a184226.js",
#     "public/controllers/jobs/filter_controller": "/assets/public/controllers/jobs/filter_controller-b261d82eaf81339f5a0abd2aa82b003d14068620.js",
#     "public/controllers/jobs/search_controller": "/assets/public/controllers/jobs/search_controller-d8013307e24aaf1572c90ceddef014dd1ba01d6a.js",
#     "public/controllers/jobs/table_results_controller": "/assets/public/controllers/jobs/table_results_controller-3c2152b25270f6b6fb4a9633bff220ae61c85d2d.js",
#     "public/controllers/kiosk_controller": "/assets/public/controllers/kiosk_controller-d511d8dcb1a58c16fee99bfdd83eb13d56205883.js",
#     "public/controllers/manage_cookies_link_reloader_controller": "/assets/public/controllers/manage_cookies_link_reloader_controller-860dd65acc9b7e59e6d7df8425743fa1bc31a37b.js",
#     "public/controllers/stream_invoker_controller": "/assets/public/controllers/stream_invoker_controller-8c60a5384fbc6af92f9c1787db9c46cd1b57403a.js",
#     "public/controllers/tracking_controller": "/assets/public/controllers/tracking_controller-9ce93909eedd3e49bf4fb551b96254eb0428d748.js",
#     "public/cookie_check": "/assets/public/cookie_check-cbc0dcb74819a75fba548d1c9d608eee96660f70.js",
#     "public/cookie_utils": "/assets/public/cookie_utils-a7b19574eb2e15d2e3fcea6214e7f1ca0d443760.js",
#     "public/cookie_utils_old": "/assets/public/cookie_utils_old-7bbfcbac3ad450acf9b8d32a5e105b533690a515.js",
#     "public/cookies": "/assets/public/cookies-ad90af9709059c4865b062902a35e41232d34f84.js",
#     "public/document_variables": "/assets/public/document_variables-04d19bbfcf7f6b5217642836528a6a127064e423.js",
#     "public/easy-autocomplete": "/assets/public/easy-autocomplete-66f0583442d73e7da7f216ce009e8aeda41f5409.js",
#     "public/explicit_consent_modal_launcher": "/assets/public/explicit_consent_modal_launcher-9091e98ce79e4185c0d9a11754a4b83d76e20da3.js",
#     "public/fixed_layout": "/assets/public/fixed_layout-0c99fd892867f17286bbc9eca4091935f603fed7.js",
#     "public/form_submission_redirection_helper": "/assets/public/form_submission_redirection_helper-c7bbcd102ae1ddd2c37dd92fd361a56089b96bae.js",
#     "public/greenhouse_job_questions": "/assets/public/greenhouse_job_questions-9a1bf3724793420c37f409ef5228ecdee65f5daa.js",
#     "public/job_questions": "/assets/public/job_questions-a5f76f5e9e063e1a9c31795b9c3d4f1feb067fc8.js",
#     "public/linkedin": "/assets/public/linkedin-d43484bb9162ffa8163b0685ec4ee7b0e52bb1f4.js",
#     "public/log_requests": "/assets/public/log_requests-4c49113823edf63f17dc9dd1c120a9efa1591968.js",
#     "public/page_init_utils": "/assets/public/page_init_utils-9b1994faad5db8bd540cc2a2002e7a525a014e1d.js",
#     "public/page_initialisation": "/assets/public/page_initialisation-7b54186b77f7a094280cb6c8af8fdcc7f717464a.js",
#     "public/pages_bs3_im": "/assets/public/pages_bs3_im-106a20afcfbedb582a5b0d9852d21bcf47d01821.js",
#     "public/pages_bs4_im": "/assets/public/pages_bs4_im-fd375c1f6041783c13a0468b8bccfd8e5254a244.js",
#     "public/pages_bs5_im": "/assets/public/pages_bs5_im-62d95a156bffb8e144c45764b870d07289b563de.js",
#     "public/post_search_control": "/assets/public/post_search_control-492b84c429ca09d593339ad417f6e027cdf36d70.js",
#     "public/public": "/assets/public/public-d4e7d8b40501012b9036b514cfb0d32846849854.js",
#     "public/rails": "/assets/public/rails-e78178d641f1af1ea46ccabc71c39d1c6a55d6bc.js",
#     "public/search_control": "/assets/public/search_control-ab4253d808e361fe37b5204386ecc722349e4cd0.js",
#     "public/third_party_libraries": "/assets/public/third_party_libraries-520f2c0314d19520d5db2d5e60795d8b4205495d.js",
#     "public/track_video": "/assets/public/track_video-f652353e9e9b8e43b027c59890a2ef2afd66ae69.js",
#     "public/track_view": "/assets/public/track_view-ebdb83cc55afbb25d7478b40a6f3fbd22035ec15.js",
#     "public/turbo": "/assets/public/turbo-72260e1eafdb911fc759f63be470c7df787efa77.js",
#     "public/uri": "/assets/public/uri-d111543a361a1ab2e0b0c70427d28556257c1618.js",
#     "public/url_utils": "/assets/public/url_utils-604f5312190e9e7dd43b81667de3a5e966c586d5.js",
#     "public/videojs": "/assets/public/videojs-4ccfd84d918752996cb9d10ba3fc6efddd9cf241.js",
#     "public/videojsandyoutube": "/assets/public/videojsandyoutube-35c7a836094295f12f14992f8483d7cc8e0bfaf7.js",
#     "common/bootstrap": "/assets/common/bootstrap-64ceb6cdd4d3bcb11840f507d7a0565a7464d884.js",
#     "common/controllers/base_controller": "/assets/common/controllers/base_controller-6dcafa6e43fe900b80ecde57178a903db1b13ad8.js",
#     "common/fetch_utils": "/assets/common/fetch_utils-e7bde16de78f38597edf86fb82026321ad862b2d.js",
#     "common/google_maps": "/assets/common/google_maps-7911cd4ad4fa28a2b29a4b605dbdd5d17b276a1d.js",
#     "common/jquery": "/assets/common/jquery-714fca85f96989df7fee64629544d1daaa279a04.js",
#     "common/namespace_jquery": "/assets/common/namespace_jquery-7bdd2a5da43bee0910aecff43359c1aa48b6f80d.js",
#     "common/phone_validation": "/assets/common/phone_validation-ed952d7a676bd39ccfa305f93aa05c5c78c887a0.js",
#     "common/ready": "/assets/common/ready-da958d74eb70633f2e35e7ce361fd9efff46546d.js",
#     "common/storage": "/assets/common/storage-2a93f1c2bb5a16bbefc7a91a403170d8cfe227c7.js"
#   }
# }</script>
# <link href="https://ga.jspm.io/npm:@hotwired/stimulus@3.2.2/dist/stimulus.js" nonce="3ShwjkmfQN/GXOvB0xuCWQ==" rel="modulepreload"/>
# <link href="/assets/stimulus-loading-1fc53fe7a488db9281d2ff88509e8f45d6119ee4.js" nonce="3ShwjkmfQN/GXOvB0xuCWQ==" rel="modulepreload"/>
# <script async="async" data-turbo-track="reload" nonce="3ShwjkmfQN/GXOvB0xuCWQ==" src="/assets/es-module-shims.min-295257ea6e233f6a8d82987e4107c1b3f9ed62ea.js"></script>
# <script nonce="3ShwjkmfQN/GXOvB0xuCWQ==" type="module">import "public/pages_bs5_im"</script>
# <script nonce="3ShwjkmfQN/GXOvB0xuCWQ==" type="module">import "public/videojsandyoutube"</script>
# <meta content="no-cache" name="turbo-cache-control"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="pK4UgFxj3dxta3ol6QKRmSiRcL8J3q1H5BgmA4EjV4RqZ5nJu7LwCKHclO4XK2qX5IN2LcBPVdpKaoOn_o_zSA" name="csrf-token"/>
# <link href="https://careers.coursera.com/jobs/search" hreflang="en-us" rel="alternate">
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="We're Hiring" id="meta_tag_description" name="description">
# <meta content="" id="meta_tag_twitter_creator" name="twitter:creator" property="twitter:creator">
# <meta content="" id="meta_tag_twitter_site" name="twitter:site" property="twitter:site"/>
# <meta content="gallery" id="meta_tag_twitter_card" name="twitter:card" property="twitter:card"/>
# <meta content="Search Page" id="meta_tag_og_title" name="og:title" property="og:title"/>
# <meta content="We're Hiring" id="meta_tag_og_description" name="og:description" property="og:description"/>
# <meta content="https://careers.coursera.com/search-page" id="meta_tag_og_url" name="og:url" property="og:url"/>
# <link href="https://ga.jspm.io/npm:@fortawesome/fontawesome-free@6.4.2/css/fontawesome.css" rel="stylesheet">
# <link href="https://ga.jspm.io/npm:@fortawesome/fontawesome-free@6.4.2/css/solid.css" rel="stylesheet"/>
# <link href="https://ga.jspm.io/npm:@fortawesome/fontawesome-free@6.4.2/css/brands.css" rel="stylesheet"/>
# <link href="https://ga.jspm.io/npm:@fortawesome/fontawesome-free@6.4.2/css/regular.css" rel="stylesheet"/>
# <link href="https://ga.jspm.io/npm:@fortawesome/fontawesome-free@6.4.2/css/v4-shims.css" rel="stylesheet"/>
# <link href="/assets/public/pages_bs5-a605e872c69abbc58b2e6a44ca574a929453c206.css" media="all" rel="stylesheet"/>
# <link href="/assets/public/themes/modern_bs5-a3ae1c31dc90570cea3f2cbc79106b2536e12688.css" media="all" rel="stylesheet"/>
# <link href="https://d25wby5c7p9100.cloudfront.net/public/uploads/32e3d0f5a59ad53b6480c220767e72b1/companies/favicons/32e3d0f5a59ad53b6480c220767e72b1/basic/favicon.png?1670847520" rel="icon" type="image/x-icon"/>
# <link href="/themes/eba0875041db9b79892abad2b9e961e2/branded_stylesheet/branded_stylesheet-1690404298.css" id="branded_style" rel="stylesheet"/>
# <link href="/themes/eba0875041db9b79892abad2b9e961e2/custom_stylesheet/custom_stylesheet-1690404298.css" id="custom_css" rel="stylesheet"/>
# <script defer="defer" src="https://583ec472ee7d.edge.sdk.awswaf.com/583ec472ee7d/ff2b87c263f8/challenge.js"></script>
# </link></meta></meta></link></head>
# <body>
# <!-- custom headers and menus -->
# <nav class="navbar navbar-expand-lg navbar-light">
# <div class="container-fluid">
# <a class="navbar-logo-as-link" href="https://careers.coursera.com/homepage">
# <img class="logo" src="https://files.clinchtalent.com/1d7f2c0f91ebf75d580f56447fa54859/eba0875041db9b79892abad2b9e961e2/Coursera.png"/>
# </a>
# <button aria-controls="navbarToggler" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarToggler" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarToggler">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item pt-3">
# <a class="nav-link btn btn-primary" href="/jobs/search">See All Jobs</a>
# </li>
# <li class="nav-item pt-3">
# <span>
# <a class="nav-link button button2" href="/me/settings"><i class="fa-solid fa-gear"></i> My Profile</a>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="alert alert-success visible-in-kiosk-mode" id="kiosk_mode_active" role="alert">Kiosk mode</div>
# <div class="page-body page not-editing">
# <script id="js_variables" nonce="3ShwjkmfQN/GXOvB0xuCWQ==">
# //<![CDATA[
# window.js_vars={};js_vars.priority_country_codes=["US","GB","AU","IE"];js_vars.cta_redirection_target="_blank";js_vars.company={"uid":"32e3d0f5a59ad53b6480c220767e72b1"};js_vars.page={"uid":"cb3d7584b21a4ff589f1b56b2f73c283"};js_vars.i18n={"job_search_form":{"jobs":"Jobs","categories":"Categories","departments":"Departments","cities":"Cities","countries":"Countries"},"enable_cookies":"We've detected that your browser cookies are disabled. Please enable your cookies to use this website","form_error":"Sorry! There was a problem sending this form"};js_vars.configuration={"field_mapping_names":["string_field_1","string_field_2","string_field_3","string_field_4","string_field_5","string_field_6","string_field_7","string_field_8","string_field_9","string_field_10","dropdown_field_1","dropdown_field_2","dropdown_field_3","dropdown_field_4","dropdown_field_5","dropdown_field_6","dropdown_field_7","dropdown_field_8","dropdown_field_9","dropdown_field_10","dropdown_field_11","dropdown_field_12","dropdown_field_13","dropdown_field_14","dropdown_field_15"]};js_vars.migrate_cookie={"active":false,"from_domain":null};js_vars.heatmap_tracking={"active":false,"links":{"create":{"url":"/api/v1/public/page_event_sequences.json"}}};js_vars.ct={"active":false,"links":{"create":{"url":"/api/v1/public/candidate_events.json"}}};js_vars.bot=true;js_vars.links={"meta_data":{"url":"/me/candidates/meta_data?company_id=32e3d0f5a59ad53b6480c220767e72b1&page_id=cb3d7584b21a4ff589f1b56b2f73c283","method":"GET","format":"json"},"consent":{"url":"/me/candidates/consent?company_id=32e3d0f5a59ad53b6480c220767e72b1","method":"GET","format":"json"},"location":{"url":"/me/candidates/location","method":"POST","format":"json"},"job_search":{"url":"https://careers.coursera.com/jobs/search"}};js_vars.nonce="3ShwjkmfQN/GXOvB0xuCWQ==";js_vars.third_party_libraries={};
# //]]>
# </script>
# <div class="page-rows">
# <div class="page-row p-t-60 p-b-60 row-background-brand_color_1 row-foreground-brand_color_3" id="page_row_0">
# <div class="page-row-inner">
# <div class="container page-row-container">
# <div class="page-row-and-new-button">
# <div class="row page-row-border">
# <div class="col-md-12">
# <div class="block-wrapper" data-uid="35507b9dcd2a336749e299ffc488aa21">
# <div class="">
# <div class="page-block" id="page_block_0_0">
# <h1 style="text-align:center;">We're Hiring</h1>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-row p-t-60 p-b-60" id="page_row_1">
# <div class="page-row-inner">
# <div class="container page-row-container">
# <div class="page-row-and-new-button">
# <div class="row page-row-border">
# <div class="col-md-12">
# <div class="block-wrapper" data-uid="d19ccc9a99e8bd675f9f99004576818a">
# <div class="block-job-search-results" data-controller="jobs--search">
# <div class="page-block" data-jobs--search-target="pageBlock" data-uid="d19ccc9a99e8bd675f9f99004576818a" id="page_block_1_0">
# <form accept-charset="UTF-8" action="https://careers.coursera.com/jobs/search" class="job-search-results-form" data-action="jobs--search#submitForm" data-jobs--search-target="form" method="get">
# <input autocomplete="off" id="block_uid" name="block_uid" type="hidden" value="d19ccc9a99e8bd675f9f99004576818a"/>
# <input autocomplete="off" id="block_index" name="block_index" type="hidden" value="0"/>
# <input autocomplete="off" id="page_row_uid" name="page_row_uid" type="hidden" value="2a57aee13867dc40aac8684e681e1ba2"/>
# <input autocomplete="off" id="page_row_index" name="page_row_index" type="hidden" value="1"/>
# <input autocomplete="off" id="page_version_uid" name="page_version_uid" type="hidden" value="327df5b6eee4e0df21adb34fe06a83bc"/>
# <input autocomplete="off" class="historical" id="page" name="page" type="hidden" value="1"/>
# <input autocomplete="off" id="location_uids" name="location_uids" type="hidden"/>
# <input autocomplete="off" data-jobs--search-target="sort" id="sort" name="sort" type="hidden"/>
# <div class="job-search-results job-search-side-filters">
# <div class="row">
# <div class="col-md-3">
# <div class="job-search-categories job-search-filter-groups" data-show-counts="true">
# <section aria-label="Filter jobs">
# <div class="job-search-filter job-search-filter-departments" data-controller="jobs--filter">
# <h4 class="job-search-filter-header departments">Department</h4>
# <label class="ada-label" for="search_departments">Search departments</label>
# <input class="form-control m-b-10 search-filter" data-action="keyup-&gt;jobs--filter#keyUp" data-jobs--filter-target="searchFilter" id="search_departments" name="search_departments" placeholder="Search" type="text" value=""/>
# <fieldset>
# <legend class="sr-only">Department</legend>
# <ul class="list-unstyled job-search-list-items departments" role="list">
# <li data-count="2" data-filter="department" data-jobs--filter-target="listItem" data-value="accounting" role="listitem">
# <label for="filter_department_1_0_0" id="label_department_1_0_0">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_0" name="department_uids[]" role="checkbox" type="checkbox" value="9a16c4dc656aeba5757f0238667553e8"/> Accounting<span class="sr-only"> (2 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_0">2</span>
# </li>
# <li data-count="1" data-filter="department" data-jobs--filter-target="listItem" data-value="credentials &amp; content" role="listitem">
# <label for="filter_department_1_0_1" id="label_department_1_0_1">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_1" name="department_uids[]" role="checkbox" type="checkbox" value="eaf2639d06c3ab4e1ea25469370172b5"/> Credentials &amp; Content<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_1">1</span>
# </li>
# <li data-count="2" data-filter="department" data-jobs--filter-target="listItem" data-value="data science" role="listitem">
# <label for="filter_department_1_0_2" id="label_department_1_0_2">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_2" name="department_uids[]" role="checkbox" type="checkbox" value="1c92f86d0d5f5463d990f73a9285dc74"/> Data Science<span class="sr-only"> (2 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_2">2</span>
# </li>
# <li data-count="1" data-filter="department" data-jobs--filter-target="listItem" data-value="degrees marketing" role="listitem">
# <label for="filter_department_1_0_3" id="label_department_1_0_3">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_3" name="department_uids[]" role="checkbox" type="checkbox" value="e3cf9e5fe588a593b7fb74a291c74746"/> Degrees Marketing<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_3">1</span>
# </li>
# <li data-count="1" data-filter="department" data-jobs--filter-target="listItem" data-value="it" role="listitem">
# <label for="filter_department_1_0_4" id="label_department_1_0_4">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_4" name="department_uids[]" role="checkbox" type="checkbox" value="faa4a99eb94007da96005d95f7463ed0"/> IT<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_4">1</span>
# </li>
# <li data-count="1" data-filter="department" data-jobs--filter-target="listItem" data-value="marketing" role="listitem">
# <label for="filter_department_1_0_5" id="label_department_1_0_5">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_5" name="department_uids[]" role="checkbox" type="checkbox" value="d125ed427a9ef6fd35d5b8c449d08d04"/> Marketing<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_5">1</span>
# </li>
# <li data-count="1" data-filter="department" data-jobs--filter-target="listItem" data-value="product &amp; content services" role="listitem">
# <label for="filter_department_1_0_6" id="label_department_1_0_6">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_6" name="department_uids[]" role="checkbox" type="checkbox" value="b91b1389989e46eda47be6c136db6082"/> Product &amp; Content Services<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_6">1</span>
# </li>
# <li data-count="1" data-filter="department" data-jobs--filter-target="listItem" data-value="product management" role="listitem">
# <label for="filter_department_1_0_7" id="label_department_1_0_7">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_department_1_0_7" name="department_uids[]" role="checkbox" type="checkbox" value="9466340e1a1a91a8f597838ce153b805"/> Product Management<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="department_count_1_0_7">1</span>
# </li>
# </ul>
# </fieldset>
# </div>
# <div class="job-search-filter job-search-filter-country-codes" data-controller="jobs--filter">
# <h4 class="job-search-filter-header country_codes">Country</h4>
# <label class="ada-label" for="search_country_codes">Search countries</label>
# <input class="form-control m-b-10 search-filter" data-action="keyup-&gt;jobs--filter#keyUp" data-jobs--filter-target="searchFilter" id="search_country_codes" name="search_country_codes" placeholder="Search" type="text" value=""/>
# <fieldset>
# <legend class="sr-only">Country</legend>
# <ul class="list-unstyled job-search-list-items country_codes" role="list">
# <li data-count="1" data-filter="country_code" data-jobs--filter-target="listItem" data-value="canada" role="listitem">
# <label for="filter_country_code_1_0_0" id="label_country_code_1_0_0">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_country_code_1_0_0" name="country_codes[]" role="checkbox" type="checkbox" value="CA"/> Canada<span class="sr-only"> (1 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="country_code_count_1_0_0">1</span>
# </li>
# <li data-count="2" data-filter="country_code" data-jobs--filter-target="listItem" data-value="colombia" role="listitem">
# <label for="filter_country_code_1_0_1" id="label_country_code_1_0_1">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_country_code_1_0_1" name="country_codes[]" role="checkbox" type="checkbox" value="CO"/> Colombia<span class="sr-only"> (2 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="country_code_count_1_0_1">2</span>
# </li>
# <li data-count="4" data-filter="country_code" data-jobs--filter-target="listItem" data-value="india" role="listitem">
# <label for="filter_country_code_1_0_2" id="label_country_code_1_0_2">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_country_code_1_0_2" name="country_codes[]" role="checkbox" type="checkbox" value="IN"/> India<span class="sr-only"> (4 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="country_code_count_1_0_2">4</span>
# </li>
# <li data-count="3" data-filter="country_code" data-jobs--filter-target="listItem" data-value="united states" role="listitem">
# <label for="filter_country_code_1_0_3" id="label_country_code_1_0_3">
# <input class="job-search-results-filter historical" data-action="jobs--search#filterChange" data-jobs--search-target="checkbox" id="filter_country_code_1_0_3" name="country_codes[]" role="checkbox" type="checkbox" value="US"/> United States<span class="sr-only"> (3 items)</span>
# </label>
# <span aria-hidden="true" class="badge float-right" id="country_code_count_1_0_3">3</span>
# </li>
# </ul>
# </fieldset>
# </div>
# </section>
# </div>
# </div>
# <div class="col-md-9 col-xs-12 col-12">
# <div class="job-search-results">
# <div class="job-search-control">
# <div class="row">
# <div class="col">
# <label class="ada-label" for="search_control_query_1_0">Search by job title, location, department, category, etc.</label>
# <div class="input-group">
# <input autocomplete="off" class="form-control historical" data-autocomplete-enabled="false" data-autocomplete-url="/jobs/search_preview?block_id=d19ccc9a99e8bd675f9f99004576818a&amp;page_id=cb3d7584b21a4ff589f1b56b2f73c283" data-jobs--search-target="freetext" id="search_control_query_1_0" maxlength="100" name="query" placeholder="Search by job title, location, department, category, etc." type="text"/>
# <span class="input-group-btn">
# <button class="btn btn-primary" id="search_control_button_1_0" name="button" type="submit">Search</button>
# </span>
# <span class="input-group-btn">
# <span class="near-me-control">
# <button class="btn btn-success near-me-btn" data-action="blocks--near-me#trackLocation" data-blocks--near-me-trackable-value="false" data-controller="blocks--near-me" id="near_me_button_1_0" name="button" type="button">Jobs Near Me</button>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="job-search-results-table job-search-results-content">
# <div class="row job-search-results-sub-search-actions">
# <div class="col-3 job-search-results-dropdown">
# </div>
# </div>
# <table class="table" data-controller="jobs--table-results" role="presentation">
# <thead aria-hidden="true">
# <tr>
# <th class="job-search-results-title">Title</th>
# <th class="job-search-results-department">Department</th>
# <th class="job-search-results-location">Location</th>
# </tr>
# </thead>
# <tbody>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Staff Machine Learning Scientist (Search Science) " href="https://careers.coursera.com/jobs/staff-machine-learning-scientist-search-science-united-states" id="link_job_title_1_0_0">
#           Staff Machine Learning Scientist (Search Science)
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_0">
# <ul>
# <li aria-label="Department: Data Science" id="department_1_0_0_0">Data Science
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: United States" id="location_1_0_0_0">United States</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Staff Accountant" href="https://careers.coursera.com/jobs/staff-accountant-india" id="link_job_title_1_0_1">
#           Staff Accountant
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_1">
# <ul>
# <li aria-label="Department: Accounting" id="department_1_0_1_0">Accounting
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: India" id="location_1_0_1_0">India</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title:  Data Science Content Strategist" href="https://careers.coursera.com/jobs/data-science-content-strategist-india" id="link_job_title_1_0_2">
#            Data Science Content Strategist
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_2">
# <ul>
# <li aria-label="Department: Credentials &amp; Content" id="department_1_0_2_0">Credentials &amp; Content
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: India" id="location_1_0_2_0">India</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: SaaS Integrations Specialist " href="https://careers.coursera.com/jobs/saas-integrations-specialist-canada" id="link_job_title_1_0_3">
#           SaaS Integrations Specialist
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_3">
# <ul>
# <li aria-label="Department: Product &amp; Content Services" id="department_1_0_3_0">Product &amp; Content Services
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: Canada" id="location_1_0_3_0">Canada</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: ServiceNow Developer" href="https://careers.coursera.com/jobs/servicenow-developer-india" id="link_job_title_1_0_4">
#           ServiceNow Developer
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_4">
# <ul>
# <li aria-label="Department: IT" id="department_1_0_4_0">IT
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: India" id="location_1_0_4_0">India</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Chief of Staff- CRO" href="https://careers.coursera.com/jobs/chief-of-staff-cro-united-states-41f0d26f-e2ee-4266-a5e1-c9df25853be6" id="link_job_title_1_0_5">
#           Chief of Staff- CRO
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_5">
# <ul>
# <li aria-label="Department: Product Management" id="department_1_0_5_0">Product Management
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: United States" id="location_1_0_5_0">United States</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Machine Learning Engineer" href="https://careers.coursera.com/jobs/machine-learning-engineer-india" id="link_job_title_1_0_6">
#           Machine Learning Engineer
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_6">
# <ul>
# <li aria-label="Department: Data Science" id="department_1_0_6_0">Data Science
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: India" id="location_1_0_6_0">India</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Enrollment Counselor, LATAM" href="https://careers.coursera.com/jobs/enrollment-counselor-latam-colombia" id="link_job_title_1_0_7">
#           Enrollment Counselor, LATAM
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_7">
# <ul>
# <li aria-label="Department: Marketing" id="department_1_0_7_0">Marketing
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: Colombia" id="location_1_0_7_0">Colombia</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Manager, Enrollment Services " href="https://careers.coursera.com/jobs/manager-enrollment-services-colombia" id="link_job_title_1_0_8">
#           Manager, Enrollment Services
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_8">
# <ul>
# <li aria-label="Department: Degrees Marketing" id="department_1_0_8_0">Degrees Marketing
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: Colombia" id="location_1_0_8_0">Colombia</li>
# </ul>
# </td>
# </tr>
# <tr data-action="click-&gt;jobs--table-results#navigate">
# <td class="job-search-results-title">
# <a aria-label="Title: Senior Tax Analyst" href="https://careers.coursera.com/jobs/senior-tax-analyst-united-states" id="link_job_title_1_0_9">
#           Senior Tax Analyst
# </a> </td>
# <td class="job-search-results-department" id="department_1_0_9">
# <ul>
# <li aria-label="Department: Accounting" id="department_1_0_9_0">Accounting
# </li> </ul>
# </td>
# <td class="job-search-results-location">
# <ul>
# <li aria-label="Location: United States" id="location_1_0_9_0">United States</li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="row pagination-container">
# <div class="col-md-4">
# <div class="table-counts" role="status">
# <p>
#         Displaying <b>all 10</b> entries
#       </p>
# </div>
# </div>
# <div class="col-md-8">
# <div class="text-right">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- custom footer -->
# <footer class="py-4 bg-light text-dark footer">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-md-4">
# <a href="https://www.coursera.org/" target="blank"><img class="footer-coursera-logo pb-2" src="https://files.clinchtalent.com/1d7f2c0f91ebf75d580f56447fa54859/eba0875041db9b79892abad2b9e961e2/coursera-logo-black-rgb.png"/></a>
# <p class="footer-text">
#               Coursera is the global online learning platform that offers
#               anyone, anywhere access to online courses and degrees from
#               world-class universities and companies.
#             </p>
# <p class="footer-text">© 2024 Coursera Inc. All rights reserved.</p>
# <span class="app-logos">
# <a href="https://itunes.apple.com/app/apple-store/id736535961?mt=8" target="blank"><img src="https://files.clinchtalent.com/1d7f2c0f91ebf75d580f56447fa54859/eba0875041db9b79892abad2b9e961e2/app-logos/app_store.svg"/></a>
# <a href="http://play.google.com/store/apps/details?id=org.coursera.android" target="blank">
# <img src="https://files.clinchtalent.com/1d7f2c0f91ebf75d580f56447fa54859/eba0875041db9b79892abad2b9e961e2/app-logos/google_play.svg"/>
# </a><br/><br/>
# <img src="https://files.clinchtalent.com/1d7f2c0f91ebf75d580f56447fa54859/eba0875041db9b79892abad2b9e961e2/app-logos/b-corp.png"/>
# </span>
# </div>
# <div class="link-column col-sm-6 col-md-2">
# <h3 class="column-header">Coursera</h3>
# <ul class="column-links">
# <li>
# <p>
# <a class="footer-link" href="https://about.coursera.org">About</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://about.coursera.org/how-coursera-works/">What We Offer</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://about.coursera.org/leadership">Leadership</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://careers.coursera.com">Careers</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/browse">Catalog</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/professional-certificates">Certificates</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/mastertrack">MasterTrack™ Certificates</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/degrees">Degrees</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/business?utm_medium=coursera&amp;utm_source=about-us&amp;utm_campaign=website&amp;utm_content=about-us-footer-to-c4b-homepage">For Enterprise</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/government?utm_medium=coursera&amp;utm_source=about-us&amp;utm_campaign=website&amp;utm_content=about-us-footer-to-c4g-homepage">For Government</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/campus?utm_medium=coursera&amp;utm_source=about-us&amp;utm_campaign=website&amp;utm_content=about-us-footer-to-c4c-homepage">For Campus</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://partnerships.coursera.org/?utm_medium=coursera&amp;utm_source=partnerships&amp;utm_campaign=website&amp;utm_content=marketing-footer-become-a-partner">Become a Partner</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/coronavirus-response">Coronavirus Response</a>
# </p>
# </li>
# </ul>
# </div>
# <div class="link-column col-sm-6 col-md-2">
# <h3 class="column-header">Community</h3>
# <ul class="column-links">
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.community/">Learners</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/about/partners">Partners</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://building.coursera.org/developer-program/">Developers</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://coursera.community/beta-tester-news-announcements-20/join-the-coursera-beta-tester-community-47">Beta Testers</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://coursera.community/gtc-news-announcements-17/join-the-coursera-global-translator-community-45">Translators</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://blog.coursera.org/">Blog</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://building.coursera.org/">Tech Blog</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/teaching-center">Teaching Center</a>
# </p>
# </li>
# </ul>
# </div>
# <div class="link-column col-sm-6 col-md-2">
# <h3 class="column-header">Connect</h3>
# <ul class="column-links">
# <li>
# <p>
# <a class="footer-link" href="https://www.facebook.com/Coursera">Facebook</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.linkedin.com/company/coursera/">LinkedIn</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://twitter.com/coursera">Twitter</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.instagram.com/coursera/">Instagram</a>
# </p>
# </li>
# </ul>
# </div>
# <div class="link-column col-sm-6 col-md-2">
# <h3 class="column-header">More</h3>
# <ul class="column-links">
# <li>
# <p>
# <a class="footer-link" href="https://about.coursera.org/press">Press</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://investor.coursera.com/">Investors</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/about/terms">Terms</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/about/privacy">Privacy</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://learner.coursera.help/hc/en-us">Help</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://learner.coursera.help/hc/en-us/articles/208280056-Accommodations-for-learners-with-disabilities">Accessibility</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/about/contact">Contact</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/articles">Articles</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://www.coursera.org/directory">Directory</a>
# </p>
# </li>
# <li>
# <p>
# <a class="footer-link" href="https://about.coursera.org/affiliates">Affiliates</a>
# </p>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <a aria-hidden="true" href="/v1/candidate_details" id="link_candidate_details" style="display: none">Candidate Details</a>
# </body>
# </html>

# %%
jobs = soup.select('table.table tbody tr')

# %%
jobs
# Out:
# [<tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Staff Machine Learning Scientist (Search Science) " href="https://careers.coursera.com/jobs/staff-machine-learning-scientist-search-science-united-states" id="link_job_title_1_0_0">
#            Staff Machine Learning Scientist (Search Science)
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_0">
#  <ul>
#  <li aria-label="Department: Data Science" id="department_1_0_0_0">Data Science
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: United States" id="location_1_0_0_0">United States</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Staff Accountant" href="https://careers.coursera.com/jobs/staff-accountant-india" id="link_job_title_1_0_1">
#            Staff Accountant
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_1">
#  <ul>
#  <li aria-label="Department: Accounting" id="department_1_0_1_0">Accounting
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: India" id="location_1_0_1_0">India</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title:  Data Science Content Strategist" href="https://careers.coursera.com/jobs/data-science-content-strategist-india" id="link_job_title_1_0_2">
#             Data Science Content Strategist
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_2">
#  <ul>
#  <li aria-label="Department: Credentials &amp; Content" id="department_1_0_2_0">Credentials &amp; Content
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: India" id="location_1_0_2_0">India</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: SaaS Integrations Specialist " href="https://careers.coursera.com/jobs/saas-integrations-specialist-canada" id="link_job_title_1_0_3">
#            SaaS Integrations Specialist
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_3">
#  <ul>
#  <li aria-label="Department: Product &amp; Content Services" id="department_1_0_3_0">Product &amp; Content Services
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: Canada" id="location_1_0_3_0">Canada</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: ServiceNow Developer" href="https://careers.coursera.com/jobs/servicenow-developer-india" id="link_job_title_1_0_4">
#            ServiceNow Developer
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_4">
#  <ul>
#  <li aria-label="Department: IT" id="department_1_0_4_0">IT
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: India" id="location_1_0_4_0">India</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Chief of Staff- CRO" href="https://careers.coursera.com/jobs/chief-of-staff-cro-united-states-41f0d26f-e2ee-4266-a5e1-c9df25853be6" id="link_job_title_1_0_5">
#            Chief of Staff- CRO
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_5">
#  <ul>
#  <li aria-label="Department: Product Management" id="department_1_0_5_0">Product Management
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: United States" id="location_1_0_5_0">United States</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Machine Learning Engineer" href="https://careers.coursera.com/jobs/machine-learning-engineer-india" id="link_job_title_1_0_6">
#            Machine Learning Engineer
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_6">
#  <ul>
#  <li aria-label="Department: Data Science" id="department_1_0_6_0">Data Science
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: India" id="location_1_0_6_0">India</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Enrollment Counselor, LATAM" href="https://careers.coursera.com/jobs/enrollment-counselor-latam-colombia" id="link_job_title_1_0_7">
#            Enrollment Counselor, LATAM
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_7">
#  <ul>
#  <li aria-label="Department: Marketing" id="department_1_0_7_0">Marketing
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: Colombia" id="location_1_0_7_0">Colombia</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Manager, Enrollment Services " href="https://careers.coursera.com/jobs/manager-enrollment-services-colombia" id="link_job_title_1_0_8">
#            Manager, Enrollment Services
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_8">
#  <ul>
#  <li aria-label="Department: Degrees Marketing" id="department_1_0_8_0">Degrees Marketing
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: Colombia" id="location_1_0_8_0">Colombia</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr data-action="click-&gt;jobs--table-results#navigate">
#  <td class="job-search-results-title">
#  <a aria-label="Title: Senior Tax Analyst" href="https://careers.coursera.com/jobs/senior-tax-analyst-united-states" id="link_job_title_1_0_9">
#            Senior Tax Analyst
#  </a> </td>
#  <td class="job-search-results-department" id="department_1_0_9">
#  <ul>
#  <li aria-label="Department: Accounting" id="department_1_0_9_0">Accounting
#  </li> </ul>
#  </td>
#  <td class="job-search-results-location">
#  <ul>
#  <li aria-label="Location: United States" id="location_1_0_9_0">United States</li>
#  </ul>
#  </td>
#  </tr>]

# %%
def extract_job_data(job_posting):
    try:
        job_title = job_posting.find('td', class_='job-search-results-title').a.text.strip()
    except AttributeError:
        job_title = ""

    try:
        department = job_posting.find('td', class_='job-search-results-department').ul.li.text.strip()
    except AttributeError:
        department = ""

    try:
        location_elem = job_posting.find('td', class_='job-search-results-location').ul.find_all('li')
        location = location_elem[0].text.strip() if location_elem else ""
    except AttributeError:
        location = ""

    return job_title, department, location

# %% [markdown]
# ## Task 4 – Define the main function:
#
# *  Create the main function that performs the specified steps.

# %%
def main(jobs):
    job_data_list = []
    for posting in jobs:
        job_data_list.append(extract_job_data(posting))

    with open('job_listings.csv', 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Title', 'Department', 'Location']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for job_data in job_data_list:
            writer.writerow({'Title': job_data[0], 'Department': job_data[1], 'Location': job_data[2]})

    print("Success! Job data extracted and saved to CSV.")
    return job_data_list

# %%
main(jobs)
# Out:
# Success! Job data extracted and saved to CSV.
# [('Staff Machine Learning Scientist (Search Science)',
#   'Data Science',
#   'United States'),
#  ('Staff Accountant', 'Accounting', 'India'),
#  ('Data Science Content Strategist', 'Credentials & Content', 'India'),
#  ('SaaS Integrations Specialist', 'Product & Content Services', 'Canada'),
#  ('ServiceNow Developer', 'IT', 'India'),
#  ('Chief of Staff- CRO', 'Product Management', 'United States'),
#  ('Machine Learning Engineer', 'Data Science', 'India'),
#  ('Enrollment Counselor, LATAM', 'Marketing', 'Colombia'),
#  ('Manager, Enrollment Services', 'Degrees Marketing', 'Colombia'),
#  ('Senior Tax Analyst', 'Accounting', 'United States')]

# %% [markdown]
# ## Conclusions:
#
# This web scraping project exemplifies a systematic and modular approach to extracting job data. The use of Python libraries like BeautifulSoup and requests, coupled with careful function design, ensures efficiency and maintainability. Robust error handling addresses potential challenges, emphasizing a thoughtful coding strategy. The project's standout features include a flexible URL generation function and clear documentation, showcasing adaptability and transparency. This portfolio piece demonstrates technical proficiency, problem-solving skills, and a commitment to producing clean, accessible code. Future improvements might explore handling complex website structures or integrating additional data sources for a more comprehensive job search tool.
